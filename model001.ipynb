# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
ele=pd.read_csv('elementsE.dat',sep='\s+|\s+', header=None)
# Out:
# /tmp/ipykernel_10527/3709958661.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   ele=pd.read_csv('elementsE.dat',sep='\s+|\s+', header=None)

# %%
ele=pd.read_csv('elementsE.csv')

# %%
ele['Eper_atom']=ele['energy'].values/(ele['natom'].values)

# %%
ele
# Out:
#    element       energy  natom   Eper_atom     structure   deltaE1   deltaE3  \
# 0       Mg  -250.234716      2 -125.117358  Li3Mg3O6.xsf -1.997042 -1.266882
# 1       Al   -26.648705      4   -6.662176  Li3Al3O6.xsf -2.901663 -2.191180
# 2       Ca  -299.382486      4  -74.845622  Li3Ca3O6.xsf -2.058899 -1.465344
# 3       Sc  -188.492581      2  -94.246290  Li3Sc3O6.xsf -3.142941 -2.806694
# 4       Ti  -357.446257      3 -119.148752  Li3Ti3O6.xsf -2.831728 -3.121942
# 5        V  -579.862777      4 -144.965694   Li3V3O6.xsf -2.479086 -2.503077
# 6       Cr  -350.791061      2 -175.395531  Li3Cr3O6.xsf -2.027494 -1.808321
# 7       Mn  -422.163307      2 -211.081653  Li3Mn3O6.xsf -1.858743 -1.520279
# 8       Co -1193.050990      4 -298.262748  Li3Co3O6.xsf -1.717378 -1.159819
# 9       Ni -1372.350049      4 -343.087512  Li3Ni3O6.xsf -1.438955 -0.915149
# 10      Cu -1614.038713      4 -403.509678  Li3Cu3O6.xsf -1.189404 -0.311439
# ...

# %%
ele
# Out:
#    element       energy  natom   Eper_atom     structure   deltaE1   deltaE3  \
# 0       Mg  -250.234716      2 -125.117358  Li3Mg3O6.xsf -1.997042 -1.266882
# 1       Al   -26.648705      4   -6.662176  Li3Al3O6.xsf -2.901663 -2.191180
# 2       Ca  -299.382486      4  -74.845622  Li3Ca3O6.xsf -2.058899 -1.465344
# 3       Sc  -188.492581      2  -94.246290  Li3Sc3O6.xsf -3.142941 -2.806694
# 4       Ti  -357.446257      3 -119.148752  Li3Ti3O6.xsf -2.831728 -3.121942
# 5        V  -579.862777      4 -144.965694   Li3V3O6.xsf -2.479086 -2.503077
# 6       Cr  -350.791061      2 -175.395531  Li3Cr3O6.xsf -2.027494 -1.808321
# 7       Mn  -422.163307      2 -211.081653  Li3Mn3O6.xsf -1.858743 -1.520279
# 8       Co -1193.050990      4 -298.262748  Li3Co3O6.xsf -1.717378 -1.159819
# 9       Ni -1372.350049      4 -343.087512  Li3Ni3O6.xsf -1.438955 -0.915149
# 10      Cu -1614.038713      4 -403.509678  Li3Cu3O6.xsf -1.189404 -0.311439
# ...

# %%
df=pd.read_csv('data3A.dat',sep='\s+|\s+', header=None)
# Out:
# /tmp/ipykernel_10527/2867981887.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   df=pd.read_csv('data3A.dat',sep='\s+|\s+', header=None)

# %%
df
# Out:
#         0   1             2        3        4         5     6     7      8   \
# 0   r3m/mg   1  Li3Mg3O6.xsf  2.98235  2.98235  14.16993  90.0  90.0  120.0
# 1   r3m/mg   2  Li2Mg3O6.xsf  3.13452  3.13452  12.15966  90.0  90.0  120.0
# 2   r3m/mg   3     Mg3O6.xsf  3.46345  3.46345   8.51232  90.0  90.0  120.0
# 3   r3m/al   1  Li3Al3O6.xsf  2.80562  2.80562  14.18373  90.0  90.0  120.0
# 4   r3m/al   2  Li2Al3O6.xsf  2.84635  2.84635  13.42188  90.0  90.0  120.0
# 5   r3m/al   3     Al3O6.xsf  2.90791  2.90791  12.03086  90.0  90.0  120.0
# 6   r3m/ca   1  Li3Ca3O6.xsf  3.33127  3.33127  14.39331  90.0  90.0  120.0
# 7   r3m/ca   2  Li2Ca3O6.xsf  3.77144  3.77144  10.13517  90.0  90.0  120.0
# 8   r3m/ca   3    Ca03O6.xsf  3.77352  3.77352   9.59075  90.0  90.0  120.0
# 9   r3m/sc   1  Li3Sc3O6.xsf  3.08281  3.08281  14.55766  90.0  90.0  120.0
# 10  r3m/sc   2  Li2Sc3O6.xsf  3.16689  3.16689  13.28214  90.0  90.0  120.0
# ...

# %%
#print(filename)
df.rename(columns={0: 'structure', 1: 'steps', 2: 'formula', 3: 'a', 4: 'b', 5: 'c', 6: 'alpha', 7: 'beta', 8: 'gamma', 9: 'volume', 10: 'energy(Ry)'}, inplace=True)
df.to_csv('DFT_calculated_3M.csv', index=False)

# %%
df
# Out:
#    structure  steps       formula        a        b         c  alpha  beta  \
# 0     r3m/mg      1  Li3Mg3O6.xsf  2.98235  2.98235  14.16993   90.0  90.0
# 1     r3m/mg      2  Li2Mg3O6.xsf  3.13452  3.13452  12.15966   90.0  90.0
# 2     r3m/mg      3     Mg3O6.xsf  3.46345  3.46345   8.51232   90.0  90.0
# 3     r3m/al      1  Li3Al3O6.xsf  2.80562  2.80562  14.18373   90.0  90.0
# 4     r3m/al      2  Li2Al3O6.xsf  2.84635  2.84635  13.42188   90.0  90.0
# 5     r3m/al      3     Al3O6.xsf  2.90791  2.90791  12.03086   90.0  90.0
# 6     r3m/ca      1  Li3Ca3O6.xsf  3.33127  3.33127  14.39331   90.0  90.0
# 7     r3m/ca      2  Li2Ca3O6.xsf  3.77144  3.77144  10.13517   90.0  90.0
# 8     r3m/ca      3    Ca03O6.xsf  3.77352  3.77352   9.59075   90.0  90.0
# 9     r3m/sc      1  Li3Sc3O6.xsf  3.08281  3.08281  14.55766   90.0  90.0
# 10    r3m/sc      2  Li2Sc3O6.xsf  3.16689  3.16689  13.28214   90.0  90.0
# ...

# %%
df1 = df[df['steps']==1]

# %%
df1
# Out:
#    structure  steps       formula        a        b         c  alpha  beta  \
# 0     r3m/mg      1  Li3Mg3O6.xsf  2.98235  2.98235  14.16993   90.0  90.0
# 3     r3m/al      1  Li3Al3O6.xsf  2.80562  2.80562  14.18373   90.0  90.0
# 6     r3m/ca      1  Li3Ca3O6.xsf  3.33127  3.33127  14.39331   90.0  90.0
# 9     r3m/sc      1  Li3Sc3O6.xsf  3.08281  3.08281  14.55766   90.0  90.0
# 12    r3m/ti      1  Li3Ti3O6.xsf  2.87715  2.87715  14.78041   90.0  90.0
# 15     r3m/v      1   Li3V3O6.xsf  2.78295  2.78295  14.76341   90.0  90.0
# 18    r3m/cr      1  Li3Cr3O6.xsf  2.71204  2.71204  14.85425   90.0  90.0
# 21    r3m/mn      1  Li3Mn3O6.xsf  2.72396  2.72396  14.62258   90.0  90.0
# 24    r3m/co      1  Li3Co3O6.xsf  2.81375  2.81375  13.79180   90.0  90.0
# 27    r3m/ni      1  Li3Ni3O6.xsf  2.85103  2.85103  14.04899   90.0  90.0
# 30    r3m/cu      1  Li3Cu3O6.xsf  2.89216  2.89216  14.25611   90.0  90.0
# ...

# %%
df2 = df[df['steps']==2]

# %%
df2 = df2.drop(['b', 'alpha','beta','gamma'],axis=1)

# %%
df2.rename(columns={ 'a': 'a1', 'c': 'c1', 'volume': 'v1', 'energy(Ry)': 'e1'}, inplace=True)

# %%
df2
# Out:
#    structure  steps       formula       a1        c1          v1           e1
# 1     r3m/mg      2  Li2Mg3O6.xsf  3.13452  12.15966  103.465163  -597.882034
# 4     r3m/al      2  Li2Al3O6.xsf  2.84635  13.42188   94.171668  -243.295376
# 7     r3m/ca      2  Li2Ca3O6.xsf  3.77144  10.13517  124.846621  -447.190894
# 10    r3m/sc      2  Li2Sc3O6.xsf  3.16689  13.28214  115.362704  -506.289403
# 13    r3m/ti      2  Li2Ti3O6.xsf  2.91972  14.59748  107.768159  -580.926460
# 16     r3m/v      2   Li2V3O6.xsf  2.79821  14.63085   99.210936  -658.043436
# 19    r3m/cr      2  Li2Cr3O6.xsf  2.73878  14.74317   95.771484  -748.913350
# 22    r3m/mn      2  Li2Mn3O6.xsf  2.76366  14.35111   94.926390  -855.812023
# 25    r3m/co      2  Li2Co3O6.xsf  2.80020  13.79083   93.648314 -1117.194552
# 28    r3m/ni      2  Li2Ni3O6.xsf  2.82879  13.72874   95.139724 -1251.435611
# 31    r3m/cu      2  Li2Cu3O6.xsf  2.89485  13.57987   98.555014 -1432.420079
# ...

# %%
df3 = df[df['steps']==3]

# %%
df3 = df3.drop(['b', 'alpha','beta','gamma'],axis=1)

# %%
df3.rename(columns={ 'a': 'a3', 'c': 'c3', 'volume': 'v3', 'energy(Ry)': 'e3'}, inplace=True)

# %%
df3
# Out:
#    structure  steps     formula       a3        c3          v3           e3
# 2     r3m/mg      3   Mg3O6.xsf  3.46345   8.51232   88.429357  -568.573377
# 5     r3m/al      3   Al3O6.xsf  2.90791  12.03086   88.102896  -213.819244
# 8     r3m/ca      3  Ca03O6.xsf  3.77352   9.59075  118.270721  -417.889449
# 11    r3m/sc      3   Sc3O6.xsf  3.54883   8.72879   95.204215  -476.978741
# 14    r3m/ti      3   Ti3O6.xsf  2.96327  14.45122  109.894602  -551.894659
# 17     r3m/v      3    V3O6.xsf  2.80337  14.84567  101.039551  -628.936114
# 20    r3m/cr      3   Cr3O6.xsf  2.71725  15.18847   97.118988  -719.766050
# 23    r3m/mn      3   Mn3O6.xsf  2.73858  14.94215   97.049454  -826.633883
# 26    r3m/co      3   Co3O6.xsf  2.78150  13.57539   90.957736 -1087.938726
# 29    r3m/ni      3   Ni3O6.xsf  2.78936  14.01083   94.407106 -1222.251174
# 32    r3m/cu      3   Cu3O6.xsf  2.88985  12.44895   90.035619 -1403.118325
# ...

# %%
df1['a1']=df2['a1'].values
df1['a3']=df3['a3'].values
df1['c1']=df2['c1'].values
df1['c3']=df3['c3'].values
df1['v1']=df2['v1'].values
df1['v3']=df3['v3'].values
df1['e1']=df2['e1'].values
df1['e3']=df3['e3'].values
# Out:
# /tmp/ipykernel_10527/3460701185.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['a1']=df2['a1'].values
# /tmp/ipykernel_10527/3460701185.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['a3']=df3['a3'].values
# /tmp/ipykernel_10527/3460701185.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
df1
# Out:
#    structure  steps       formula        a        b         c  alpha  beta  \
# 0     r3m/mg      1  Li3Mg3O6.xsf  2.98235  2.98235  14.16993   90.0  90.0
# 3     r3m/al      1  Li3Al3O6.xsf  2.80562  2.80562  14.18373   90.0  90.0
# 6     r3m/ca      1  Li3Ca3O6.xsf  3.33127  3.33127  14.39331   90.0  90.0
# 9     r3m/sc      1  Li3Sc3O6.xsf  3.08281  3.08281  14.55766   90.0  90.0
# 12    r3m/ti      1  Li3Ti3O6.xsf  2.87715  2.87715  14.78041   90.0  90.0
# 15     r3m/v      1   Li3V3O6.xsf  2.78295  2.78295  14.76341   90.0  90.0
# 18    r3m/cr      1  Li3Cr3O6.xsf  2.71204  2.71204  14.85425   90.0  90.0
# 21    r3m/mn      1  Li3Mn3O6.xsf  2.72396  2.72396  14.62258   90.0  90.0
# 24    r3m/co      1  Li3Co3O6.xsf  2.81375  2.81375  13.79180   90.0  90.0
# 27    r3m/ni      1  Li3Ni3O6.xsf  2.85103  2.85103  14.04899   90.0  90.0
# 30    r3m/cu      1  Li3Cu3O6.xsf  2.89216  2.89216  14.25611   90.0  90.0
# ...

# %%
df1.rename(columns={ 'volume': 'v', 'energy(Ry)': 'e'}, inplace=True)
# Out:
# /tmp/ipykernel_10527/1288357408.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.rename(columns={ 'volume': 'v', 'energy(Ry)': 'e'}, inplace=True)

# %%
df1
# Out:
#    structure  steps       formula        a        b         c  alpha  beta  \
# 0     r3m/mg      1  Li3Mg3O6.xsf  2.98235  2.98235  14.16993   90.0  90.0
# 3     r3m/al      1  Li3Al3O6.xsf  2.80562  2.80562  14.18373   90.0  90.0
# 6     r3m/ca      1  Li3Ca3O6.xsf  3.33127  3.33127  14.39331   90.0  90.0
# 9     r3m/sc      1  Li3Sc3O6.xsf  3.08281  3.08281  14.55766   90.0  90.0
# 12    r3m/ti      1  Li3Ti3O6.xsf  2.87715  2.87715  14.78041   90.0  90.0
# 15     r3m/v      1   Li3V3O6.xsf  2.78295  2.78295  14.76341   90.0  90.0
# 18    r3m/cr      1  Li3Cr3O6.xsf  2.71204  2.71204  14.85425   90.0  90.0
# 21    r3m/mn      1  Li3Mn3O6.xsf  2.72396  2.72396  14.62258   90.0  90.0
# 24    r3m/co      1  Li3Co3O6.xsf  2.81375  2.81375  13.79180   90.0  90.0
# 27    r3m/ni      1  Li3Ni3O6.xsf  2.85103  2.85103  14.04899   90.0  90.0
# 30    r3m/cu      1  Li3Cu3O6.xsf  2.89216  2.89216  14.25611   90.0  90.0
# ...

# %%
df123 = df1.drop(['b', 'alpha','beta','gamma','structure','steps'],axis=1)

# %%
df123
# Out:
#          formula        a         c           v            e       a1  \
# 0   Li3Mg3O6.xsf  2.98235  14.16993  109.148197  -612.611441  3.13452
# 3   Li3Al3O6.xsf  2.80562  14.18373   96.689640  -258.043756  2.84635
# 6   Li3Ca3O6.xsf  3.33127  14.39331  138.328496  -461.850788  3.77144
# 9   Li3Sc3O6.xsf  3.08281  14.55766  119.816563  -521.008902  3.16689
# 12  Li3Ti3O6.xsf  2.87715  14.78041  105.960292  -595.441803  2.91972
# 15   Li3V3O6.xsf  2.78295  14.76341   99.021355  -672.581604  2.79821
# 18  Li3Cr3O6.xsf  2.71204  14.85425   94.617887  -763.472817  2.73878
# 21  Li3Mn3O6.xsf  2.72396  14.62258   93.963071  -870.382350  2.76366
# 24  Li3Co3O6.xsf  2.81375  13.79180   94.563003 -1131.800951  2.80020
# 27  Li3Ni3O6.xsf  2.85103  14.04899   98.895951 -1266.029681  2.82879
# 30  Li3Cu3O6.xsf  2.89216  14.25611  103.270250 -1447.076079  2.89485
# 33  Li3Zn3O6.xsf  2.92561  14.51925  107.623852 -1620.514104  2.95824
# ...

# %%
df123['da1'] = -(df123['a']-df123['a1'])*100/df123['a']
df123['da3'] = -(df123['a']-df123['a3'])*100/df123['a']
df123['dc1'] = -(df123['c']-df123['c1'])*100/df123['c']
df123['dc3'] = -(df123['c']-df123['c3'])*100/df123['c']
df123['dv1'] = -(df123['v']-df123['v1'])*100/df123['v']
df123['dv3'] = -(df123['v']-df123['v3'])*100/df123['v']

# %%
df123
# Out:
#          formula        a         c           v            e       a1  \
# 0   Li3Mg3O6.xsf  2.98235  14.16993  109.148197  -612.611441  3.13452
# 3   Li3Al3O6.xsf  2.80562  14.18373   96.689640  -258.043756  2.84635
# 6   Li3Ca3O6.xsf  3.33127  14.39331  138.328496  -461.850788  3.77144
# 9   Li3Sc3O6.xsf  3.08281  14.55766  119.816563  -521.008902  3.16689
# 12  Li3Ti3O6.xsf  2.87715  14.78041  105.960292  -595.441803  2.91972
# 15   Li3V3O6.xsf  2.78295  14.76341   99.021355  -672.581604  2.79821
# 18  Li3Cr3O6.xsf  2.71204  14.85425   94.617887  -763.472817  2.73878
# 21  Li3Mn3O6.xsf  2.72396  14.62258   93.963071  -870.382350  2.76366
# 24  Li3Co3O6.xsf  2.81375  13.79180   94.563003 -1131.800951  2.80020
# 27  Li3Ni3O6.xsf  2.85103  14.04899   98.895951 -1266.029681  2.82879
# 30  Li3Cu3O6.xsf  2.89216  14.25611  103.270250 -1447.076079  2.89485
# 33  Li3Zn3O6.xsf  2.92561  14.51925  107.623852 -1620.514104  2.95824
# ...

# %%
Li   =    -129.34419679/9

# %%
ele['structure'] = df123['formula'].values

# %%
Li   =    -129.34419679/9
o = -256.511036/8
ry=13.6057
ele['deltaE1'] = ry*(df123['e'].values-3*ele['Eper_atom'].values - 3*Li - 6*o)/12
ele['deltaE3'] = ry*(df123['e3'].values-3*ele['Eper_atom'].values - 0*Li - 6*o)/9
ele['volt1'] = ry*(df123['e'].values- df123['e1'].values - 1*Li)/1
ele['volt_av'] = ry*(df123['e'].values- df123['e3'].values - 3*Li)/3

# %%
ele
# Out:
#    element       energy  natom   Eper_atom     structure   deltaE1   deltaE3  \
# 0       Mg  -250.234716      2 -125.117358  Li3Mg3O6.xsf -1.997042 -1.266882
# 1       Al   -26.648705      4   -6.662176  Li3Al3O6.xsf -2.901663 -2.191180
# 2       Ca  -299.382486      4  -74.845622  Li3Ca3O6.xsf -2.058899 -1.465344
# 3       Sc  -188.492581      2  -94.246290  Li3Sc3O6.xsf -3.142941 -2.806694
# 4       Ti  -357.446257      3 -119.148752  Li3Ti3O6.xsf -2.831728 -3.121942
# 5        V  -579.862777      4 -144.965694   Li3V3O6.xsf -2.479086 -2.503077
# 6       Cr  -350.791061      2 -175.395531  Li3Cr3O6.xsf -2.027494 -1.808321
# 7       Mn  -422.163307      2 -211.081653  Li3Mn3O6.xsf -1.858743 -1.520279
# 8       Co -1193.050990      4 -298.262748  Li3Co3O6.xsf -1.717378 -1.159819
# 9       Ni -1372.350049      4 -343.087512  Li3Ni3O6.xsf -1.438955 -0.915149
# 10      Cu -1614.038713      4 -403.509678  Li3Cu3O6.xsf -1.189404 -0.311439
# ...

# %%
x=range(0,14)

# %%
plt.figure(figsize=(12,8))
plt.xlabel("Elements")
plt.ylabel("Voltage/FormaE (V/eV)")
plt.xticks(x, labels, rotation='vertical')

plt.plot(x, ele['deltaE1'], c="g", alpha=1, marker=r'$\clubsuit$', label='FormaE1')
plt.plot(x, ele['deltaE3'], c="m", alpha=1, marker=r'$*$', label='FormaE2')
plt.plot(x, ele['volt1'], c="r", alpha=1, marker=r'$o$', label='volt')
plt.plot(x, ele['volt_av'], c="b", alpha=1, marker=r'$+$', label='av-volt')
plt.legend(['Formation_E_per_atom','Formation_E_per_atom_after_deliethiation','Voltage', 'average_volt']) 
plt.grid(True)
#plt.show()

# %%
plt.figure(figsize=(12,8))
plt.xlabel("Elements")
plt.ylabel("Voltage/FormaE (V/eV)")
plt.xticks(x, labels, rotation='vertical')

plt.plot(x, ele['deltaE1'], c="g", alpha=1, marker=r'$\clubsuit$', label='FormaE1')
plt.plot(x, ele['deltaE3'], c="m", alpha=1, marker=r'$*$', label='FormaE2')
plt.plot(x, ele['volt_av'], c="b", alpha=1, marker=r'$+$', label='av-volt')
plt.legend(['Formation_E_per_atom','Formation_E_per_atom_after_deliethiation', 'average_volt']) 
plt.grid(True)
#plt.show()

# %%
#ele.to_csv('elementsE.csv', index=None)

# %%
#df123.to_csv('df123.csv', index=None)
